# %% [markdown]
# ## 0. Setup

# %%
import os


batch_size = 2
threads = 4

# Should point to the root folder of the cropped images, see the tutorial for preparing IXI
dataset_folder = os.path.join(os.path.expanduser('~'), 'data', 'IXI', 'cropped')

# %% [markdown]
# ## 1. Instantiate the generator

# %%
from pyment.data import AsyncNiftiGenerator, NiftiDataset


dataset = NiftiDataset.from_folder(dataset_folder, target='id')

# Set up a preprocessor to normalize the voxel values
preprocessor = lambda x: x/255

generator = AsyncNiftiGenerator(dataset, preprocessor=preprocessor, 
                                batch_size=batch_size, threads=threads)
# Out:
# 2021-07-03 15:16:33,503 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI051-HH-1328-T1: Missing image
# 2021-07-03 15:16:33,504 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI387-HH-2101-T1: Missing image
# 2021-07-03 15:16:33,505 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI260-HH-1805-T1: Missing image
# 2021-07-03 15:16:33,505 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI538-HH-2411-T1: Missing image
# 2021-07-03 15:16:33,505 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI554-Guys-1068-T1: Missing image
# 2021-07-03 15:16:33,506 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI227-Guys-0813-T1: Missing image
# 2021-07-03 15:16:33,506 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI070-Guys-0767-T1: Missing image
# 2021-07-03 15:16:33,507 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI163-HH-1621-T1: Missing image
# 2021-07-03 15:16:33,507 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI105-HH-1471-T1: Missing image
# 2021-07-03 15:16:33,507 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI537-HH-2378-T1: Missing image
# 2021-07-03 15:16:33,508 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI128-HH-1470-T1: Missing image
# 2021-07-03 15:16:33,508 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI483-HH-2177-T1: Missing image
# 2021-07-03 15:16:33,509 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI521-HH-2353-T1: Missing image
# 2021-07-03 15:16:33,509 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI061-Guys-0715-T1: Missing image
# 2021-07-03 15:16:33,510 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI002-Guys-0828-T1: Missing image
# 2021-07-03 15:16:33,511 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI299-Guys-0893-T1: Missing image
# 2021-07-03 15:16:33,512 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI071-Guys-0770-T1: Missing image
# 2021-07-03 15:16:33,512 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI523-Guys-1056-T1: Missing image
# 2021-07-03 15:16:33,513 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI274-HH-2294-T1: Missing image
# 2021-07-03 15:16:33,513 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI587-Guys-1128-T1: Missing image
# 2021-07-03 15:16:33,514 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI441-HH-2154-T1: Missing image
# 2021-07-03 15:16:33,516 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI584-Guys-1129-T1: Missing image
# 2021-07-03 15:16:33,519 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI490-Guys-1018-T1: Missing image
# 2021-07-03 15:16:33,521 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI607-Guys-1097-T1: Missing image
# 2021-07-03 15:16:33,522 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI196-Guys-0805-T1: Missing image
# 2021-07-03 15:16:33,523 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI073-Guys-0755-T1: Missing image
# 2021-07-03 15:16:33,523 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI081-Guys-0855-T1: Missing labels
# 2021-07-03 15:16:33,524 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI623-Guys-1076-T1: Missing labels
# 2021-07-03 15:16:33,524 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI637-HH-2785-T1: Missing labels
# 2021-07-03 15:16:33,525 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI333-IOP-0926-T1: Missing labels
# 2021-07-03 15:16:33,525 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI435-IOP-1040-T1: Missing labels
# 2021-07-03 15:16:33,526 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI457-Guys-0984-T1: Missing labels
# 2021-07-03 15:16:33,528 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI337-IOP-0929-T1: Missing labels
# 2021-07-03 15:16:33,530 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI228-Guys-0822-T1: Missing labels
# 2021-07-03 15:16:33,532 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI088-Guys-0758-T1: Missing labels
# 2021-07-03 15:16:33,532 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI638-HH-2786-T1: Missing labels
# 2021-07-03 15:16:33,533 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI340-IOP-0915-T1: Missing labels
# 2021-07-03 15:16:33,533 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI345-IOP-0928-T1: Missing labels
# 2021-07-03 15:16:33,535 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI341-Guys-0906-T1: Missing labels
# 2021-07-03 15:16:33,535 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI661-HH-2788-T1: Missing labels
# 2021-07-03 15:16:33,536 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI589-Guys-1080-T1: Missing labels
# 2021-07-03 15:16:33,536 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI347-IOP-0927-T1: Missing labels
# 2021-07-03 15:16:33,542 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI117-Guys-0763-T1: Missing labels
# 2021-07-03 15:16:33,542 - WARNING - pyment.data.datasets.nifti_dataset: Skipping IXI643-HH-2787-T1: Missing labels

# %% [markdown]
# ## 2. Sanity check the generator

# %%
import matplotlib.pyplot as plt
import numpy as np

batches = 0

for X, y in generator:
    fig, ax = plt.subplots(1, batch_size)
    fig.suptitle(f'Batch {batches+1}')
    
    for i in range(batch_size):
        ax[i].imshow(X[i,83,:,:])
        ax[i].axis('off')
        ax[i].set_title(y[i])
        
    plt.show()
    
    print(f'Image batch shape: {X.shape}')
    print(f'Image voxel value range: {round(np.amin(X), 2)}-{round(np.amax(X), 2)}')
    
    batches += 1
    
    if batches > 5:
        break
# Out:
# Image batch shape: (2, 167, 212, 160)
# Image voxel value range: 0.0-0.78
# Image batch shape: (2, 167, 212, 160)
# Image voxel value range: 0.0-0.61
# Image batch shape: (2, 167, 212, 160)
# Image voxel value range: 0.0-0.72
# Image batch shape: (2, 167, 212, 160)
# Image voxel value range: 0.0-0.75
# Image batch shape: (2, 167, 212, 160)
# Image voxel value range: 0.0-0.8
# Image batch shape: (2, 167, 212, 160)
# Image voxel value range: 0.0-0.73

# %% [markdown]
# ## 3. Configure the model

# %%
from pyment.models import RegressionSFCN


model = RegressionSFCN(weights='brain_age', include_top=False)

# %% [markdown]
# ## 4. Generate feature vectors

# %%
dataset.target = 'id'

generator.reset()

preds, ids = model.predict(generator, return_labels=True)
# Out:
# 100%|██████████| 269/269 [17:04<00:00,  3.81s/it]

# %%
import numpy as np
import pandas as pd

from sklearn.manifold import TSNE


np.random.seed(42)

features = [f'Feature {x}' for x in range(64)]
predictions = pd.DataFrame(preds, index=ids, columns=features)
labels = pd.DataFrame({'age': dataset._labels['age'], 'sex': dataset._labels['sex']}, index=dataset.ids)
df = predictions.join(labels)

tsne = TSNE(n_components=2, perplexity=50, init='pca')
components = tsne.fit_transform(df[features])

female = df['sex'] == 'F'
male = df['sex'] == 'M'

fig = plt.figure(figsize=(10, 10))

fig.suptitle('t-SNE reduced feature vectors')

vmin = np.amin(df['age'])
vmax = np.amax(df['age'])

f = plt.scatter(components[female,0], components[female,1], marker='o', 
                c=df.loc[female, 'age'].values, vmin=vmin, vmax=vmax)
m = plt.scatter(components[male,0], components[male,1], marker='^', 
                c=df.loc[male, 'age'].values, vmin=vmin, vmax=vmax)

clb = plt.colorbar(f)
clb.ax.set_title('Age')

plt.gca().axis('off')

plt.legend([f, m], ['Female', 'Male'])

plt.show()
