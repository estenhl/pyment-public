# %%
import os

from pyment.models import RankingSFCN, RegressionSFCN, SoftClassificationSFCN
from pyment.postprocessing import get_postprocessing


IMAGE_FOLDER = os.path.join(os.path.expanduser('~'), 'data', 'IXI', 'freesurfer+fsl')
LABELS_FILE = os.path.join(os.path.expanduser('~'), 'data', 'IXI', 'IXI.xls')
MODEL = SoftClassificationSFCN
WEIGHTS = 'brain-age-2022'
# Min and max age should match that of the model (e.g. 3-95 for brain-age-2022),
# not that of the dataset
MIN_AGE = 3
MAX_AGE = 95

model = MODEL(weights=WEIGHTS, prediction_range=(MIN_AGE, MAX_AGE))
# Out:
# 2024-03-26 19:05:45.028500: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2024-03-26 19:05:45.028531: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-03-26 19:05:45.028540: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-03-26 19:05:45.028563: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-03-26 19:05:45.028578: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
import nibabel as nib
import numpy as np
import pandas as pd

from tqdm import tqdm


labels = pd.read_excel(LABELS_FILE)
predictions = []

for imageid in tqdm(os.listdir(IMAGE_FOLDER)[:50]):
    path = os.path.join(IMAGE_FOLDER, imageid, 'mri', 'cropped.nii.gz')
    subjectid = int(imageid[3:6])
    
    if not os.path.isfile(path):
        print(f'Skipping {imageid}: Missing cropped.nii.gz')
        continue
    elif subjectid not in labels['IXI_ID'].values:
        print(f'Skipping {imageid}: Missing labels')
        continue

    age = labels.loc[labels['IXI_ID'] == subjectid, 'AGE'].values[0]
    
    img = nib.load(path)
    img = img.get_fdata()
    
    # Adds an extra dimension to fake the image being part of a batch
    img = np.expand_dims(img, 0)
    
    prediction = model.predict(img, verbose=0)[0]
    prediction = model.postprocess(prediction)
    predictions.append({
        'imageid': imageid,
        'age': age,
        'prediction': prediction
    })

predictions = pd.DataFrame(predictions)
# Out:
#   1%|▊                                                                                                                   | 3/419 [00:09<20:56,  3.02s/it]
# Skipping IXI661-HH-2788-T1: Missing labels
#  32%|████████████████████████████████████▏                                                                             | 133/419 [06:10<13:17,  2.79s/it]
# Skipping IXI589-Guys-1080-T1: Missing labels
#  36%|█████████████████████████████████████████▎                                                                        | 152/419 [06:58<11:50,  2.66s/it]
# Skipping IXI637-HH-2785-T1: Missing labels
#  37%|██████████████████████████████████████████▋                                                                       | 157/419 [07:10<11:07,  2.55s/it]
# Skipping IXI340-IOP-0915-T1: Missing labels
#  44%|██████████████████████████████████████████████████                                                                | 184/419 [08:29<11:56,  3.05s/it]
# Skipping IXI347-IOP-0927-T1: Missing labels
#  48%|██████████████████████████████████████████████████████▉                                                           | 202/419 [09:19<09:43,  2.69s/it]
# Skipping IXI457-Guys-0984-T1: Missing labels
#  51%|█████████████████████████████████████████████████████████▉                                                        | 213/419 [09:41<07:14,  2.11s/it]
# Skipping IXI299-Guys-0893-T1: Missing cropped.nii.gz
#  54%|█████████████████████████████████████████████████████████████▍                                                    | 226/419 [10:06<06:32,  2.03s/it]
# Skipping IXI241-Guys-0833-T1: Missing cropped.nii.gz
#  60%|████████████████████████████████████████████████████████████████████▎                                             | 251/419 [10:54<05:43,  2.05s/it]
# Skipping IXI039-HH-1261-T1: Missing cropped.nii.gz
#  68%|█████████████████████████████████████████████████████████████████████████████▎                                    | 284/419 [12:01<05:07,  2.28s/it]
# Skipping IXI081-Guys-0855-T1: Missing labels
#  79%|██████████████████████████████████████████████████████████████████████████████████████████▌                       | 333/419 [13:48<03:13,  2.25s/it]
# Skipping IXI083-HH-1357-T1: Missing cropped.nii.gz
# Skipping IXI345-IOP-0928-T1: Missing labels
#  81%|████████████████████████████████████████████████████████████████████████████████████████████▌                     | 340/419 [13:59<02:36,  1.98s/it]
# Skipping IXI333-IOP-0926-T1: Missing labels
#  83%|██████████████████████████████████████████████████████████████████████████████████████████████▋                   | 348/419 [14:15<02:30,  2.13s/it]
# Skipping IXI038-Guys-0729-T1: Missing cropped.nii.gz
#  85%|█████████████████████████████████████████████████████████████████████████████████████████████████▍                | 358/419 [14:36<02:20,  2.31s/it]
# Skipping IXI087-Guys-0768-T1: Missing cropped.nii.gz
#  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████            | 375/419 [15:12<01:41,  2.31s/it]
# Skipping IXI638-HH-2786-T1: Missing labels
#  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████         | 386/419 [15:34<01:13,  2.22s/it]
# Skipping IXI643-HH-2787-T1: Missing labels
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 419/419 [16:46<00:00,  2.40s/it]

# %%
import plotly.graph_objs as go

traces = [
    go.Scatter(
        x=[MIN_AGE, MAX_AGE],
        y=[MIN_AGE, MAX_AGE],
        showlegend=False
    ),
    go.Scatter(
        x=predictions['prediction'],
        y=predictions['age'],
        mode='markers',
        showlegend=False
    )
]

mae = np.mean(np.abs(predictions['prediction'] - predictions['age']))
print(mae)
layout = go.Layout(
    title={'x': 0.5, 'text': f'{model.__class__.__name__} with weights={WEIGHTS}'},
    xaxis={'range': [MIN_AGE, MAX_AGE], 'title': 'Prediction'},
    yaxis={'range': [MIN_AGE, MAX_AGE], 'title': 'Age'},
    width=512,
    height=512,
    annotations=[{'x':70, 'y':15, 'text': f'MAE={mae:.2f}', 'showarrow': False}]
)

figure = go.Figure(traces, layout)
figure.show()
# Out:
# 7.318435202495394
